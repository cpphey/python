# %%
import pandas as pd

# %%
list = [[1,2],[3,4]]
rowNames = ["r1","r2"]
colNames = ["col1","col2"]
df = pd.DataFrame(list,index=rowNames,columns=colNames)
df
# Out:
#     col1  col2
# r1     1     2
# r2     3     4

# %%
df["col1"]
# Out:
# r1    1
# r2    3
# Name: col1, dtype: int64

# %%
df.at["r1","col1"]
# Out:
# 1

# %%
df.iat[1,1]
# Out:
# 4

# %%
df2=df.copy(deep=True)

df2["col3"]=[10,11]
df2.loc["r3"]=[100,110,120]
df2
# Out:
#     col1  col2  col3
# r1     1     2    10
# r2     3     4    11
# r3   100   110   120

# %%
df2.iloc[0:2,0:2]=[[10,20],[30,40]]
df2.iloc[0:2,0:2]
# Out:
#     col1  col2
# r1    10    20
# r2    30    40

# %%
df2
# Out:
#     col1  col2  col3
# r1    10    20    10
# r2    30    40    11
# r3   100   110   120

# %%
df2.iat[0,0]
# Out:
# 10

# %%
df2.at["r1","col1"]
# Out:
# 10

# %%
df2.iloc[0]
# Out:
# col1    10
# col2    20
# col3    10
# Name: r1, dtype: int64

# %%
df2.loc["r1"]
# Out:
# col1    10
# col2    20
# col3    10
# Name: r1, dtype: int64

# %%
df2["col1"]
# Out:
# r1     10
# r2     30
# r3    100
# Name: col1, dtype: int64

# %%
df2.iloc[:,0]
# Out:
# r1     10
# r2     30
# r3    100
# Name: col1, dtype: int64

# %%
df2.index
# Out:
# Index(['r1', 'r2', 'r3'], dtype='object')

# %%
df2.columns
# Out:
# Index(['col1', 'col2', 'col3'], dtype='object')

# %%
df2[df2.columns[0]]
# Out:
# r1     10
# r2     30
# r3    100
# Name: col1, dtype: int64

# %%
df2.loc[:,"col1"]
# Out:
# r1     10
# r2     30
# r3    100
# Name: col1, dtype: int64

# %%
df2.loc[df2.index[0] , : ] #singe row
# Out:
# col1    10
# col2    20
# col3    10
# Name: r1, dtype: int64

# %%
df2.loc[:,df2.columns[0]] #refer to single columns
# Out:
# r1     10
# r2     30
# r3    100
# Name: col1, dtype: int64

# %%
df2
# Out:
#     col1  col2  col3
# r1    10    20    10
# r2    30    40    11
# r3   100   110   120

# %%
df2['col1']
# Out:
# r1     10
# r2     30
# r3    100
# Name: col1, dtype: int64

# %%
df2[['col1','col3']]
# Out:
#     col1  col3
# r1    10    10
# r2    30    11
# r3   100   120

# %%
df2.loc[  :  ,df2.columns[0] ]
# Out:
# r1     10
# r2     30
# r3    100
# Name: col1, dtype: int64

# %%
df2.loc[ df2.index[0] , : ]
# Out:
# col1    10
# col2    20
# col3    10
# Name: r1, dtype: int64

# %%
df2
# Out:
#     col1  col2  col3
# r1    10    20    10
# r2    30    40    11
# r3   100   110   120

# %%
df2[df2["col1"] > 10]
# Out:
#     col1  col2  col3
# r2    30    40    11
# r3   100   110   120

# %%
df2[df2.index == "r1"]
# Out:
#     col1  col2  col3
# r1    10    20    10

# %%
df2[df2.index.isin ( ["r1","r3"] )]
# Out:
#     col1  col2  col3
# r1    10    20    10
# r3   100   110   120

# %%
df2.index.map({"r1":1 , "r2" : 2, "r3" : 3})
# Out:
# Index([1, 2, 3], dtype='int64')

# %%
df2.values.tolist()
# Out:
# [[10, 20, 10], [30, 40, 11], [100, 110, 120]]

# %%
df3 = pd.DataFrame([[1,2],[3,4,5],[6,7]])
df3
# Out:
#    0  1    2
# 0  1  2  NaN
# 1  3  4  5.0
# 2  6  7  NaN

# %%
df2.shape
# Out:
# (3, 3)

# %%
type(df2.shape)
# Out:
# tuple

# %%
df3.columns=[0,1,2]
df3.index=[0,1,2]
df3
# Out:
#    0  1    2
# 0  1  2  NaN
# 1  3  4  5.0
# 2  6  7  NaN

# %%
import copy
l1=[0,1,2]
l2 = copy.deepcopy(l1)

# %%
df2.iloc[0,:].between(0,10)
# Out:
# col1     True
# col2    False
# col3     True
# Name: r1, dtype: bool

# %%
df2
# Out:
#     col1  col2  col3
# r1    10    20    10
# r2    30    40    11
# r3   100   110   120
