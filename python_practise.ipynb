# %%
print("hello")
# Out:
# hello

# %%
l=[0,1,2] #List

# %%
t=(0,1,2) #Tuple

# %%
d={1:2,3:4} #Dict

# %%
d
# Out:
# {1: 2, 3: 4}

# %%
d[1]
# Out:
# 2

# %%
l[0] = 10
l
# Out:
# [10, 1, 2]

# %%
t[0] = 10 # tuple wont work
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 t[0] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
l = [0,1,2]
l.extend([3,4,5])
l
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
l = [0,1,2]
l.append([3,4,5]) #extend vs append
l
# Out:
# [0, 1, 2, [3, 4, 5]]

# %%
#Trick with zip
l1 = [ 0 , 1, 2]
l2 = [ 10, 11, 12]
[print(f"{a} : {b}") for a,b in zip(l1, l2)]
# Out:
# 0 : 10
# 1 : 11
# 2 : 12
# [None, None, None]

# %%
for _ in l1: 
    print(_)
# Out:
# 0
# 1
# 2

# %%
_2
# Out:
# [None, None, None]

# %%
[1]*3
# Out:
# [1, 1, 1]

# %%
l=[1]*3
l
# Out:
# [1, 1, 1]

# %%
l[0] = 0
l
# Out:
# [0, 1, 1]

# %%
l = range(3)
l
# Out:
# range(0, 3)

# %%
l = []
for a in range(3): 
    l.append(a)

l
# Out:
# [0, 1, 2]

# %%
l = []
[l.append(a) for a in range(3)]
l
# Out:
# [0, 1, 2]
